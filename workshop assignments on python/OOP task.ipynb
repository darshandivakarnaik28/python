# %% [markdown]
# ### TASK 1 STUDENT CLASS

# %%
class student:
    def __init__(self,name,age,course):
        self.name=name
        self.age=age
        self.course=course
    def display_details(self):
        return f"name:{self.name}\nage:{self.age}\ncourse:{self.course}"
a=student("darshan",21,"CSE")
print(a.display_details())
# Out:
# name:darshan
# age:21
# course:CSE

# %% [markdown]
# ### TASK 2 EMPLOYEE CLASS

# %%
class employee:
    def __init__(self,name,salary):
        self.name=name
        self.salary=salary
    def display_info(self,age):
        self.age=age
        return f"name:{self.name}\nAge:{self.age}"
    def yearly_salary(self):
        salary=self.salary*12
        return f"yearly salary is :{salary}"
b=employee("Darshan",20000)
print(b.display_info(23))
print(b.yearly_salary())
# Out:
# name:Darshan
# Age:23
# yearly salary is :240000

# %% [markdown]
# ### TASK 3 PRODUCT CLASS

# %%
class product:
    def __init__(self,pid,name,price):
        self.pid=pid
        self.name=name
        self.price=price
    def display_product(self):
        return f"product id:{self.pid}\nproduct name:{self.name}\nprice:{self.price}"
        
    def apply_discount(self):
        return f"price after 10% discount is :{self.price-self.price*0.1}"
c=product(1,"mixer",1500)
print(c.display_product())
print(c.apply_discount())
# Out:
# product id:1
# product name:mixer
# price:1500
# price after 10% discount is :1350.0

# %% [markdown]
# ### TASK 4: LIBRARY BOOK CLASS

# %%
class book:
    def __init__(self,bid,bname):
        self.bid=bid
        self.bname=bname
    def issue_book(self,name):    
        self.name=name
        return f"{self.bname} book is issued to {self.name}"
    def return_book(self,date):
        self.date=date
        return f"{self.bname} book is returned at {self.date}"
d=book(101,"happy")
print(d.issue_book("darshan"))
print(d.return_book("12-08-2026"))
# Out:
# happy book is issued to darshan
# happy book is returned at 12-08-2026

# %% [markdown]
# ### TASK 5 MINI PROJECT

# %%
class students:
    
    def __init__(self,usn,name,age,course):
        self.usn=usn
        self.name=name
        self.age=age
        self.course=course
    def add_student(self,s):
        s.append({"usn":self.usn,
                  "name":self.name,
                  "age":self.age,
                  "course":self.course})
        
    def display(self):
        return f"name:{self.name}\nusn:{self.usn}\nage:{self.age}\ncourse:{self.course}\n"
s=[]
student1=students("darshu","23cs016",21,"CSE")
student1.add_student(s)
print(student1.display())
student2=students("chethu","23ec006",21,"ECE")
student2.add_student(s)
print(student2.display())
# Out:
# name:23cs016
# usn:darshu
# age:21
# course:CSE
#
# name:23ec006
# usn:chethu
# age:21
# course:ECE

# %% [markdown]
# ### DAY 2 (AUG 5) Encapsulation + Class Variables + Static Methods

# %% [markdown]
# ### TASK 1: Bank Account

# %%
class bank:
    def __init__(self,name,accno,balance):
        self.name=name
        self.accno=accno
        self.__balance=balance
    def deposit(self,amount):
        self.amount=amount
        self.__balance+=amount
        return self.__balance
    def withdraw(self,amount):
        self.amount=amount
        self.__balance-=amount
        return self.__balance
b=bank("darshu",2528,30000)
#print(b.__balance)
print(b.deposit(500))
print(b.withdraw(500))
# Out:
# 30500
# 30000

# %% [markdown]
# ### TASK 2: Employee

# %%
class employee:
    def __init__(self,name,eid,salary):
        self.name=name
        self.eid=eid
        self.__salary=salary
    def update_salary(self,amount):
        if isinstance(amount,(int,float)):
            if amount>0 and amount<100000:
                if amount>self.__salary:
                    self.__salary=amount
                else:
                    return f"amount must be greater than account balance"
            else:
                return f"Amount is greate than 0 and less the 100000"
        else:
            return f"Enter a number"
        return f"slary:{self.__salary}"
e=employee("darshu",123,10000)
print(e.update_salary(3000))
print(e.update_salary("12"))
print(e.update_salary(0))
print(e.update_salary(20000))
#print(e.__salary)
# Out:
# amount must be greater than account balance
# Enter a number
# Amount is greate than 0 and less the 100000
# slary:20000
# 20000

# %% [markdown]
# ### TASK 3 Student Counter

# %%
class student:
    college="GECR"
    count=0
    def __init__(self,name,usn):
        self.name=name
        self.usn=usn
        student.count+=1
print(student.college)
print(student.count)
s1=student("darshu",123)
s2=student("chethu",124)
print(student.count)
# Out:
# GECR
# 0
# 2

# %% [markdown]
# ### TASK 4 Utility Class

# %%
class utility:
    @staticmethod
    def is_even(n):
        if n%2==0:
            return True
        else:
            return False
    @staticmethod
    def is_odd(n):
        if n%2!=0:
            return True
        else:
            return False
u=utility()
print(u.is_even(4))
print(u.is_odd(5))
# Out:
# True
# True

# %% [markdown]
# ### TASK 5 ATM System

# %%
class atm:
    def __init__(self,accno,name):
        self.accno=accno
        self.name=name
        self.__balance=10000
    def deposit(self,amount):
        self.__balance+=amount
    def withdraw(self,amount):
        self.__balance-=amount
    def check_balance(self):
        return self.__balance
a=atm(123,"darshu")
a.deposit(1000)
a.withdraw(500)
print(a.check_balance())
# Out:
# 10500

# %% [markdown]
# ### DAY 3 (AUG6) Inheritance + Method Overriding

# %% [markdown]
# ### TASK 1

# %%
class person:
    def __init__(self,name):
        self.name=name
    def walk(self):
        return f"{self.name} is walking"
    def speak(self):
        return f"{self.name} is speaking"
class student(person):
    def __init__(self,name,course):
        super().__init__(name)
        self.course=course
    def display(self):
        return f"{self.name} he is a student from {self.course}"

s=student("darshu","CSE")
print(s.walk())
print(s.speak())
print(s.display())
# Out:
# darshu is walking
# darshu is speaking
# darshu he is a student from CSE

# %% [markdown]
# ### TASK 2

# %%
class vehicle:
    def __init__(self,number,color):
        self.number=number
        self.color=color
    def move(self):
        return f"vechicle is moving"
class Car(vehicle):
    def __init__(self,number,color):
        super().__init__(number,color)
        self.wheel=4
    def move(self):
        return f"Car is moving with the {self.wheel} wheels"
class Bike(vehicle):
    def __init__(self,number,color):
        super().__init__(number,color)
        self.wheel=2
    def move(self):
        return f"Bike is moving with th {self.wheel} wheels"
C=Car(123,"red")
B=Bike(456,"silver")
print(C.move())

print(B.move())
# Out:
# Car is moving with the 4 wheels
# Bike is moving with th 2 wheels

# %% [markdown]
# ### TASK 3

# %%
class animal:
   def sound(self,sound="generic sound"):
        print("animal make sound")
class dog(animal):
    def sound(self,sound="Bark"):
        return f"Dog make a sound {sound}"
class cat(animal):
    def sound(self,sound="Meow Meow"):
        return f"cat make a sound {sound}"
d=dog()
c=cat()
print(d.sound())
print(c.sound())
print(d.sound("bow bow"))
print(c.sound("chir chir"))
# Out:
# Dog make a sound Bark
# cat make a sound Meow Meow
# Dog make a sound bow bow
# cat make a sound chir chir

# %% [markdown]
# ### TASK 4

# %%
class employee:
    def __init__(self,emp_id,emp_name):
        self.emp_id=emp_id
        self.emp_name=emp_name
    def work(self):
        print("Employee is working")
class developer(employee):
    def __init__(self,emp_id,emp_name,works):
        super().__init__(emp_id,emp_name)
        self.works=works
    def work(self):
        return f"{self.emp_id} {self.emp_name} worked as {self.works}"
class tester(employee):
    def __init__(self,emp_id,emp_name,works):
        super().__init__(emp_id,emp_name)
        self.works=works
    def work(self):
        return f"{self.emp_id} {self.emp_name} worked as {self.works}"
d=developer(123,"darshu","developer")
t=tester(456,"chethu","tester")
print(d.work())
print(t.work())
# Out:
# 123 darshu worked as developer
# 456 chethu worked as tester

# %% [markdown]
# ### TASK 5

# %%
class person:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def display(self):
        print(f"Name:{self.name}, Age:{self.age}")
class student(person):
    def __init__(self,name,age,sid):
        super().__init__(name,age)
        self.sid=sid
    def display(self):
        super().display()
        print(f"Student ID:{self.sid}\n")
class teacher(person):
    def __init__(self,name,age,sub):
        super().__init__(name,age)
        self.sub=sub
    def display(self):
        super().display()
        print(f"Subject:{self.sub}\n")
class admin(person):
    def __init__(self,name,age,role):
        super().__init__(name,age)
        self.role=role
    def display(self):
        super().display()
        print(f"Admin role:{self.role}\n")

s=student("darshu",21,16)
t=teacher("mam",30,"Maths")
a=admin("sir",45,"Registrar")
s.display()
t.display()
a.display()
# Out:
# Name:darshu, Age:21
# Student ID:16
#
# Name:mam, Age:30
# Subject:Maths
#
# Name:sir, Age:45
# Admin role:Registrar

# %% [markdown]
# ### DAY 4 (AUG 7) Polymorphism + Abstraction

# %% [markdown]
# ### TASK 1

# %%
from abc import ABC ,abstractmethod
class payment(ABC):
    def __init__(self,amount):
        self.amount=amount
    @abstractmethod
    def pay(self):
        pass        
class upi(payment):
    def __init__(self,amount):
        super().__init__(amount)
    def pay(self):
        print(f"{self.amount} payed successfully via UPI")
class creditcard(payment):
    def __init__(self,amount):
        super().__init__(amount)
    def pay(self):
        print(f"{self.amount} payed successfully via Credit Card")
class wallet(payment):
    def __init__(self,amount):
        super().__init__(amount)
    def pay(self):
        print(f"{self.amount} payed successfully via Wallet")
u=upi(100)
c=creditcard(70)
w=wallet(50)
u.pay()
c.pay()
w.pay()
# Out:
# 100 payed successfully via UPI
# 70 payed successfully via Credit Card
# 50 payed successfully via Wallet

# %% [markdown]
# ### TASK 2

# %%
import math
class shape:
    def area_(self):
        pass
class circle(shape):
    def __init__(self,radius):
        self.radius=radius
    def area_(self):
        print(f"Area of circle is = {math.pi*self.radius**2}")
class rectangle(shape):
    def __init__(self,width,height):
        self.width=width
        self.height=height
    def area_(self):
        print(f"Area of rectangal is = {self.width*self.height}")
c=circle(4)
r=rectangle(2,3)
c.area_()
r.area_()
# Out:
# Area of circle is = 50.26548245743669
# Area of rectangal is = 6

# %% [markdown]
# ### TASK 3

# %%
from abc import ABC,abstractmethod
class vehicle(ABC):
    @abstractmethod
    def run(self):
        pass
class car(vehicle):
    def __init__(self):
        self.speed=180
    def run(self):
        print(f"Car maximun speed is :{self.speed}")
         
class bike(vehicle):
    def __init__(self):
        self.speed=100
    def run(self):
        print(f"Bike maximum speed is :{self.speed}")
c=car()
c.run()
b=bike()
b.run()
# Out:
# Car maximun speed is :180
# Bike maximum speed is :100

# %% [markdown]
# ### TASK 4

# %%
from abc import ABC , abstractmethod
class employee(ABC):
    def __init__(self,empid,name):
        self.empid=empid
        self.name=name
    @abstractmethod
    def display(self):
        print(f"Employee id :{self.empid}\nEmployee name:{self.empname}")
class FullTimeEmployee(employee):
    def __init__(self,empid,name,hour):
        super().__init__(empid,name)
        self.hour=hour
    def display(self):
        print(f"FullTime work is :{self.hour} hours")

class ParttTimeEmployee(employee):
    def __init__(self,empid,name,slot):
        super().__init__(empid,name)
        self.slot=slot
    def display(self):
        print(f"Part Time work is :{self.slot}am slot")
f=FullTimeEmployee(123,"Darshu",9)
p=ParttTimeEmployee(456,"Chethu","10-12")
f.display()
p.display()
# Out:
# FullTime work is :9 hours
# Part Time work is :10-12am slot

# %% [markdown]
# ### TASK 5

# %%
from abc import ABC,abstractmethod
class notification(ABC):
    @abstractmethod
    def send(self):
        pass
class emailnotification(notification):
    def send(self):
        print(f"Notification push from Email")
class smsnotification(notification):
    def send(self):
        print(f"Notification push from SMS")
class pushnotification(emailnotification,smsnotification):
    def send(self):
        emailnotification.send(self)
        smsnotification.send(self)
p=pushnotification()
p.send()
# Out:
# Notification push from Email
# Notification push from SMS

# %% [markdown]
# ### PHASE 2 :Task Phase + video record

# %% [markdown]
# ### 1 Movie Ticket Booking System

# %%
class movie:
    def __init__(self,title,duration):
        self.title=title
        self.duration=duration
class theater:
    def __init__(self,name,seat_no):
        self.name=name
        self.seat_no=seat_no
        self.__seat=[{"seat_no":self.seat_no}]

    def display_seat(self):
        for i in range(self.__seat):
            for j in range(10):
                print(f"seat{i}\t")
            print("\n")
    def reserve_seat(self,seat_no):
        for i in self.__seat:
            if i["seat_no"]==seat_no:
                print(f"{seat_no} is already booked ,pls select another seat")
            else:
                i["seat_no"]=seat_no
                print(f"{seat_no} is booked successfully")
    def release_seat(self,seat_no):
        for i in self.__seat:
            i["seat_no"]=None
        else:
            print(f"{seat_no} is released")

class show:
    def __init__(self,movie,theater,time):
        self.movie=movie
        self.theater=theater
        self.time=time

class person:
    def __init__(self,name,mob_no):
        self.name=name
        self.mob_no=mob_no

class customer(person):
    def __init__(self,name,mob_no,cus_id):
        super().__init__(name,mob_no)
        self.cus_id=cus_id

class ticket:
